# %%
# 1. Download the dataset : Titanic
# 2. Load the dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset('titanic')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
data.shape
# Out:
# (891, 15)

# %%
# 3. Perform Below Visualizations.
# ● Univariate Analysis
# ● Bi - Variate Analysis
# ● Multi - Variate Analysis

# %%
# Uni Variate Analysis

# %%
list = data['alive'].unique()

# %%
pie = data['alive'].value_counts()
plt.pie(pie,autopct='%.2f%%',labels=list)
# Out:
# ([<matplotlib.patches.Wedge at 0x24d03715d00>,
# ...
#  [Text(-0.3925749350994583, 1.0275626113924428, 'no'),
#   Text(0.3925750313068116, -1.0275625746369201, 'yes')],
#  [Text(-0.21413178278152267, 0.5604886971231505, '61.62%'),
#   Text(0.21413183525826085, -0.5604886770746836, '38.38%')])

# %%
plt.hist(data['fare'],color='purple')
# Out:
# (array([732., 106.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(data['fare'])
# Out:
# C:\Users\vilasini\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.boxplot(data['age'])
# Out:
# C:\Users\vilasini\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
a = data['age'].value_counts().plot.bar()

# %%
# Bi- Variate Analysis

# %%
sns.scatterplot(data.age,data.alive)
# Out:
# C:\Users\vilasini\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='alive'>

# %%
sns.jointplot(data.age,data.alive)
# Out:
# C:\Users\vilasini\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
hmap = data.corr()
hmap
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(hmap,annot=True)
# Out:
# <AxesSubplot:>

# %%
# Multi Variate Analysis

# %%
sns.pairplot(data)

# %%
#4. Perform descriptive statistics on the dataset.

# %%
# mean, median, mode

# %%
data.mean()
# Out:
# C:\Users\vilasini\AppData\Local\Temp\ipykernel_18604\531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
data.median()
# Out:
# C:\Users\vilasini\AppData\Local\Temp\ipykernel_18604\4184645713.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.median()
# survived       0.0000
# pclass         3.0000
# age           28.0000
# sibsp          0.0000
# parch          0.0000
# fare          14.4542
# adult_male     1.0000
# alone          1.0000
# dtype: float64

# %%
data.mode()
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  24.0      0      0  8.05        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True    C  Southampton    no   True

# %%
# Skewness

# %%
data.skew()
# Out:
# C:\Users\vilasini\AppData\Local\Temp\ipykernel_18604\1188251951.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.skew()
# survived      0.478523
# pclass       -0.630548
# age           0.389108
# sibsp         3.695352
# parch         2.749117
# fare          4.787317
# adult_male   -0.420431
# alone        -0.420431
# dtype: float64

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Dist Plot

# %%
sns.distplot(data['fare'],color='red')
sns.distplot(data['pclass'],color='blue')
# Out:
# C:\Users\vilasini\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='pclass', ylabel='Density'>

# %%
# Kurtosis

# %%
data.kurt()
# Out:
# C:\Users\vilasini\AppData\Local\Temp\ipykernel_18604\2907027414.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.kurt()
# survived      -1.775005
# pclass        -1.280015
# age            0.178274
# sibsp         17.880420
# parch          9.778125
# fare          33.398141
# adult_male    -1.827345
# alone         -1.827345
# dtype: float64

# %%
# Range

# %%
x = data.max()
# Out:
# C:\Users\vilasini\AppData\Local\Temp\ipykernel_18604\668095369.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   x = data.max()

# %%
y = data.min()
# Out:
# C:\Users\vilasini\AppData\Local\Temp\ipykernel_18604\3492690688.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y = data.min()

# %%
r = x - y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:163, in _na_arithmetic_op(left, right, op, is_cmp)
#     162 try:
# --> 163     result = func(left, right)
#     164 except TypeError:
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:128, in _evaluate_numexpr(op, op_str, a, b)
#     127 if result is None:
# --> 128     result = _evaluate_standard(op, op_str, a, b)
#     130 return result
#
# ...

# %%
# IQR

# %%
q3 = data.age.quantile(0.75)
q1 = data.age.quantile(0.25)
q3,q1
# Out:
# (35.0, 22.0)

# %%
IQR = q3 - q1
IQR
# Out:
# 13.0

# %%
data.var()
# Out:
# C:\Users\vilasini\AppData\Local\Temp\ipykernel_18604\445316826.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.var()
# survived         0.237315
# pclass           0.696263
# age            154.415590
# sibsp            1.224631
# parch            0.654027
# fare          2487.352750
# adult_male       0.240453
# alone            0.240227
# dtype: float64

# %%
# 5. Handle the Missing values.

# %%
data.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data.isnull().any()
# Out:
# survived       False
# pclass         False
# sex            False
# age             True
# sibsp          False
# parch          False
# fare           False
# embarked        True
# class          False
# who            False
# adult_male     False
# deck            True
# embark_town     True
# alive          False
# alone          False
# dtype: bool

# %%
data['age'].fillna(data['age'].mean(),inplace=True)

# %%
data
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data['deck'].fillna(data['deck'].mode(),inplace=True)
data['embark_town'].fillna(data['embark_town'].mode(),inplace=True)

# %%
# 6. Find the outliers and replace the outliers

# %%
sns.boxplot(data['age'])
# Out:
# C:\Users\vilasini\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
p99 = data.age.quantile(0.99)
p99
# Out:
# 65.0

# %%
data = data[data.age<=p99]

# %%
data
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
# 7. Check for Categorical columns and perform encoding.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.sex = le.fit_transform(df.sex)
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500        S  Third    man
# 1         1       1    0  38.0      1      0  71.2833        C  First  woman
# 2         1       3    0  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    0  35.0      1      0  53.1000        S  First  woman
# 4         0       3    1  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
data = pd.get_dummies(df,columns=['embark_town'])
data
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    1  22.0      1      0   7.2500        S   Third
# 1           1       1    0  38.0      1      0  71.2833        C   First
# 2           1       3    0  26.0      0      0   7.9250        S   Third
# 3           1       1    0  35.0      1      0  53.1000        S   First
# 4           0       3    1  35.0      0      0   8.0500        S   Third
# ..        ...     ...  ...   ...    ...    ...      ...      ...     ...
# 886         0       2    1  27.0      0      0  13.0000        S  Second
# 887         1       1    0  19.0      0      0  30.0000        S   First
# 888         0       3    0   NaN      1      2  23.4500        S   Third
# 889         1       1    1  26.0      0      0  30.0000        C   First
# 890         0       3    1  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck alive  alone  embark_town_Cherbourg  \
# ...

# %%
data = pd.get_dummies(df,columns=['embarked'])
data
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare   class    who  \
# 0           0       3    1  22.0      1      0   7.2500   Third    man
# 1           1       1    0  38.0      1      0  71.2833   First  woman
# 2           1       3    0  26.0      0      0   7.9250   Third  woman
# 3           1       1    0  35.0      1      0  53.1000   First  woman
# 4           0       3    1  35.0      0      0   8.0500   Third    man
# ..        ...     ...  ...   ...    ...    ...      ...     ...    ...
# 886         0       2    1  27.0      0      0  13.0000  Second    man
# 887         1       1    0  19.0      0      0  30.0000   First  woman
# 888         0       3    0   NaN      1      2  23.4500   Third  woman
# 889         1       1    1  26.0      0      0  30.0000   First    man
# 890         0       3    1  32.0      0      0   7.7500   Third    man
#
#      adult_male deck  embark_town alive  alone  embarked_C  embarked_Q  \
# ...

# %%
data = pd.get_dummies(df,columns=['class'])
data
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked    who  \
# 0           0       3    1  22.0      1      0   7.2500        S    man
# 1           1       1    0  38.0      1      0  71.2833        C  woman
# 2           1       3    0  26.0      0      0   7.9250        S  woman
# 3           1       1    0  35.0      1      0  53.1000        S  woman
# 4           0       3    1  35.0      0      0   8.0500        S    man
# ..        ...     ...  ...   ...    ...    ...      ...      ...    ...
# 886         0       2    1  27.0      0      0  13.0000        S    man
# 887         1       1    0  19.0      0      0  30.0000        S  woman
# 888         0       3    0   NaN      1      2  23.4500        S  woman
# 889         1       1    1  26.0      0      0  30.0000        C    man
# 890         0       3    1  32.0      0      0   7.7500        Q    man
#
#      adult_male deck  embark_town alive  alone  class_First  class_Second  \
# ...

# %%
data = pd.get_dummies(df,columns=['who'])
data
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    1  22.0      1      0   7.2500        S   Third
# 1           1       1    0  38.0      1      0  71.2833        C   First
# 2           1       3    0  26.0      0      0   7.9250        S   Third
# 3           1       1    0  35.0      1      0  53.1000        S   First
# 4           0       3    1  35.0      0      0   8.0500        S   Third
# ..        ...     ...  ...   ...    ...    ...      ...      ...     ...
# 886         0       2    1  27.0      0      0  13.0000        S  Second
# 887         1       1    0  19.0      0      0  30.0000        S   First
# 888         0       3    0   NaN      1      2  23.4500        S   Third
# 889         1       1    1  26.0      0      0  30.0000        C   First
# 890         0       3    1  32.0      0      0   7.7500        Q   Third
#
#      adult_male deck  embark_town alive  alone  who_child  who_man  who_woman
# ...

# %%
df.adult_male = le.fit_transform(df.adult_male)
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500        S  Third    man
# 1         1       1    0  38.0      1      0  71.2833        C  First  woman
# 2         1       3    0  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    0  35.0      1      0  53.1000        S  First  woman
# 4         0       3    1  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0           1  NaN  Southampton    no  False
# 1           0    C    Cherbourg   yes  False
# 2           0  NaN  Southampton   yes   True
# 3           0    C  Southampton   yes  False
# 4           1  NaN  Southampton    no   True

# %%
df.alive = le.fit_transform(df.alive)
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500        S  Third    man
# 1         1       1    0  38.0      1      0  71.2833        C  First  woman
# 2         1       3    0  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    0  35.0      1      0  53.1000        S  First  woman
# 4         0       3    1  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town  alive  alone
# 0           1  NaN  Southampton      0  False
# 1           0    C    Cherbourg      1  False
# 2           0  NaN  Southampton      1   True
# 3           0    C  Southampton      1  False
# 4           1  NaN  Southampton      0   True

# %%
df.alone = le.fit_transform(df.alone)
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500        S  Third    man
# 1         1       1    0  38.0      1      0  71.2833        C  First  woman
# 2         1       3    0  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    0  35.0      1      0  53.1000        S  First  woman
# 4         0       3    1  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town  alive  alone
# 0           1  NaN  Southampton      0      0
# 1           0    C    Cherbourg      1      0
# 2           0  NaN  Southampton      1      1
# 3           0    C  Southampton      1      0
# 4           1  NaN  Southampton      0      1

# %%
# 8. Split the data into dependent and independent variables

# %%
y = df['alive']

# %%
x = df.drop(columns=['alive'],axis=1)

# %%
x
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    1  22.0      1      0   7.2500        S   Third
# 1           1       1    0  38.0      1      0  71.2833        C   First
# 2           1       3    0  26.0      0      0   7.9250        S   Third
# 3           1       1    0  35.0      1      0  53.1000        S   First
# 4           0       3    1  35.0      0      0   8.0500        S   Third
# ..        ...     ...  ...   ...    ...    ...      ...      ...     ...
# 886         0       2    1  27.0      0      0  13.0000        S  Second
# 887         1       1    0  19.0      0      0  30.0000        S   First
# 888         0       3    0   NaN      1      2  23.4500        S   Third
# 889         1       1    1  26.0      0      0  30.0000        C   First
# 890         0       3    1  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town  alone
# ...

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: alive, Length: 891, dtype: int32

# %%
# 9. Scale the independent variables

# %%
name = x.columns

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()
data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    1  22.0      1      0   7.2500        S  Third
# 1         1       1    0  38.0      1      0  71.2833        C  First
# 2         1       3    0  26.0      0      0   7.9250        S  Third
# 3         1       1    0  35.0      1      0  53.1000        S  First
# 4         0       3    1  35.0      0      0   8.0500        S  Third
#
#    adult_male deck  embark_town alive  alone  who_child  who_man  who_woman
# 0        True  NaN  Southampton    no  False          0        1          0
# 1       False    C    Cherbourg   yes  False          0        0          1
# 2       False  NaN  Southampton   yes   True          0        0          1
# 3       False    C  Southampton   yes  False          0        0          1
# 4        True  NaN  Southampton    no   True          0        1          0

# %%
features_scaled = df.drop(columns=['embarked','class','adult_male','deck','embark_town','alone'],axis=1)
x_scaled = scale.fit_transform(features_scaled)
x_scaled
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [128], in <cell line: 2>()
#       1 features_scaled = df.drop(columns=['embarked','class','adult_male','deck','embark_town','alone'],axis=1)
# ----> 2 x_scaled = scale.fit_transform(features_scaled)
#       3 x_scaled
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
#     851     # fit method of arity 1 (unsupervised transformation)
# --> 852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
#     855     return self.fit(X, y, **fit_params).transform(X)
#
# ...

# %%
# 10. Split the data into training and testing

# %%
x = pd.DataFrame(x,columns=name)

# %%
# train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,y_train,x_test,y_test = train_test_split(x,y,test_size=0.20,random_state=24)

# %%
x_train.head()
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked   class  \
# 68          1       3    0  17.0      4      2   7.9250        S   Third
# 768         0       3    1   NaN      1      0  24.1500        Q   Third
# 722         0       2    1  34.0      0      0  13.0000        S  Second
# 94          0       3    1  59.0      0      0   7.2500        S   Third
# 640         0       3    1  20.0      0      0   7.8542        S   Third
#
#        who  adult_male deck  embark_town  alone
# 68   woman           0  NaN  Southampton      0
# 768    man           1  NaN   Queenstown      0
# 722    man           1  NaN  Southampton      1
# 94     man           1  NaN  Southampton      1
# 640    man           1  NaN  Southampton      1

# %%
y_train.head()
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked  class  \
# 169         0       3    1  28.0      0      0  56.4958        S  Third
# 556         1       1    0  48.0      1      0  39.6000        C  First
# 206         0       3    1  32.0      1      0  15.8500        S  Third
# 71          0       3    0  16.0      5      2  46.9000        S  Third
# 677         1       3    0  18.0      0      0   9.8417        S  Third
#
#        who  adult_male deck  embark_town  alone
# 169    man           1  NaN  Southampton      1
# 556  woman           0    A    Cherbourg      0
# 206    man           1  NaN  Southampton      0
# 71   woman           0  NaN  Southampton      0
# 677  woman           0  NaN  Southampton      1

# %%
x_test.head()
# Out:
# 68     1
# 768    0
# 722    0
# 94     0
# 640    0
# Name: alive, dtype: int32

# %%
y_test.head()
# Out:
# 169    0
# 556    1
# 206    0
# 71     0
# 677    1
# Name: alive, dtype: int32
